# %% [markdown]
# # Determining which parts of the city attract which types of food truck

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# 1. Import packages and read dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# reading the CSV file
df = pd.read_csv('Mobile_Food_Facility_Permit.csv')

# %%
df.head()
# Out:
#    locationid                                          Applicant FacilityType  \
# 0      735318                                   Ziaurehman Amini    Push Cart
# 1     1612654  Sunset Mercantile/Outer Sunset Farmers Market ...        Truck
# 2     1658690                                        Bonito Poke        Truck
# 3     1652620                         Off the Grid Services, LLC        Truck
# 4     1652621                         Off the Grid Services, LLC        Truck
#
#         cnn                                LocationDescription  \
# 0  30727000                   MARKET ST: DRUMM ST intersection
# 1   1835000   37TH AVE: QUINTARA ST to RIVERA ST (2100 - 2199)
# 2   3528000  CALIFORNIA ST: SANSOME ST to LEIDESDORFF ST (4...
# 3   2953000           BERRY ST: 03RD ST to 04TH ST (100 - 199)
# 4   3143000           BROADWAY: DAVIS ST to FRONT ST (50 - 99)
#
#              Address blocklot block  lot       permit  ...  \
# 0  5 THE EMBARCADERO  0234017  0234  017   15MFF-0159  ...
# 1      2155 37TH AVE  2094006  2094  006  22MFF-00031  ...
# 2  430 CALIFORNIA ST  0239029  0239  029  22MFF-00070  ...
# 3       185 BERRY ST  3803005  3803  005  22MFF-00036  ...
# 4        90 BROADWAY  0140007  0140  007  22MFF-00036  ...
#
#                  Approved  Received  PriorPermit          ExpirationDate  \
# 0                     NaN  20151231            0  03/15/2016 12:00:00 AM
# 1                     NaN  20220421            0  11/15/2022 12:00:00 AM
# 2  11/09/2022 12:00:00 AM  20221109            0  11/15/2023 12:00:00 AM
# 3  11/22/2022 12:00:00 AM  20221019            0  11/15/2023 12:00:00 AM
# 4  11/22/2022 12:00:00 AM  20221019            0  11/15/2023 12:00:00 AM
#
#                                     Location  Fire Prevention Districts  \
# 0  (37.794331003246846, -122.39581105302317)                        4.0
# 1   (37.74732654654123, -122.49628067270531)                        1.0
# 2   (37.793262206923096, -122.4017890913628)                        4.0
# 3   (37.77632714778992, -122.39179682107691)                        6.0
# 4  (37.799260113502285, -122.39961794865545)                        3.0
#
#   Police Districts Supervisor Districts  Zip Codes Neighborhoods (old)
# 0              1.0                 10.0    28855.0                 6.0
# 1              8.0                  3.0    29491.0                35.0
# 2              1.0                 10.0    28854.0                 6.0
# 3              2.0                  9.0    28856.0                20.0
# 4              1.0                 10.0    28860.0                 6.0
#
# [5 rows x 29 columns]

# %% [markdown]
# 2. Data understanding and cleaning

# %%
df.shape
# Out:
# (481, 29)

# %%
for column in df.columns:
    print(column, df[column].isna().sum())
# Out:
# locationid 0
# Applicant 0
# FacilityType 8
# cnn 0
# LocationDescription 15
# Address 0
# blocklot 10
# block 10
# lot 10
# permit 0
# Status 0
# FoodItems 6
# X 33
# Y 33
# Latitude 0
# Longitude 0
# Schedule 0
# dayshours 394
# NOISent 481
# Approved 130
# Received 0
# PriorPermit 0
# ExpirationDate 23
# Location 0
# Fire Prevention Districts 34
# Police Districts 34
# Supervisor Districts 34
# Zip Codes 33
# Neighborhoods (old) 34

# %%
df.groupby('FoodItems').size().reset_index(name='count').sort_values('count', ascending=False)
# Out:
#                                              FoodItems  count
# 33   Cold Truck: Sandwiches: Noodles:  Pre-packaged...     38
# 15   Burgers: melts: hot dogs: burritos:sandwiches:...     37
# 32   Cold Truck: Pre-packaged sandwiches: snacks: f...     33
# 30   Cold Truck: Hamburger: cheeseburgers: hot dogs...     23
# 65   Ice Cream: Pre-Packaged Chips: Candies: Bottle...     21
# ..                                                 ...    ...
# 63                            Ice Cream & Waffle Cones      1
# 62                Hotdogs: chips: soda: nuts: crackers      1
# 61     Hot dogs: sausages: cheesesteaks: chips: drinks      1
# 60   Hot dogs: condiments: soft pretzels: soft drin...      1
# 140  various styles of hot dogs & sausages: chips: ...      1
#
# [141 rows x 2 columns]

# %%
foodtype=[]
for row in df.groupby('FoodItems').size().reset_index(name='count').sort_values('count', ascending=False)['FoodItems']:
    foodtype.append(row)

# %%
foodtype
# Out:
# ['Cold Truck: Sandwiches: Noodles:  Pre-packaged Snacks: Candy: Desserts Various Beverages',
#  'Burgers: melts: hot dogs: burritos:sandwiches: fries: onion rings: drinks',
#  'Cold Truck: Pre-packaged sandwiches: snacks: fruit: various beverages',
#  'Cold Truck: Hamburger: cheeseburgers: hot dogs: hot sandwiches: cold sandwiches: egg muffins: cup of noodles: corn dogs: canned soup: coffee: hot cocoa: hot tea: gatorade: juice: milk: soda: water: fruits: fruit salad: rice pudding: yogurt: candy bars: chips: cookies: donuts: granola bars: muffins',
#  'Ice Cream: Pre-Packaged Chips: Candies: Bottled Water & Canned SODA',
#  'COLD TRUCK. Deli: bbq chicken skewer: Chinese spring roll: Chinese fried rice/noodle: fried chicken leg/wing: bbq chicken sandwich: chicken cheese burger: burrito: lumpia. Snack: sunflower seeds: muffins: chips: snickers: kit-kat: 10 types of chocolate. Drinks: Coke: 7-Up: Dr. Pepper: Pepsi: Redbull: Vitamin Water: Rockstar: Coconut Juice: Water. Hot drinks: coffee: tea.',
#  'Cold Truck: Soft drinks: cup cakes: potato chips: cookies: gum: sandwiches (hot & cold): peanuts: muffins: coff (hot & cold): water: juice: yoplait: milk: orange juice: sunflower seeds: can foods: burritos: buscuits: chimichangas: rice krispies',
#  'Cold Truck: Corn Dogs: Noodle Soups: Candy: Pre-packaged Snacks: Sandwiches: Chips: Coffee: Tea: Various Beverages',
#  'Hot dogs: condiments: soft pretzels: soft drinks: coffee: cold beverages: pastries: bakery goods: cookies: ice cream: candy: soups: churros: chestnuts: nuts: fresh fruit: fruit juices: desserts: potato chips and popcorn.',
#  'Cold Truck: Breakfast: Sandwiches: Salads: Pre-Packaged Snacks: Beverages',
#  'Cold Truck: Hot/Cold Sandwiches: Water: Soda: Juice: Snacks: Milk: Candies: Canned Food: Soups: Cup of Noodles: Fruit: Salad',
#  'Bonito Poke Bowls & Various Drinks',
#  'Cold Truck: Burrito: Corn Dog: Salads: Sandwiches: Quesadilla: Tacos: Fried Rice: Cow Mein: Chinese Rice: Noodle Plates: Soup: Bacon: Eggs: Ham: Avacado: Sausages: Beverages',
#  'Mexican Food: Yucatan Food: Street Food',
#  'everything except for hot dogs',
#  'Various types of meat: veggie: and seafood bowls.',
#  'Hot coffee: iced coffee: hot chocolate: tea: pastries',
#  "Artisan Pizzas (Margherita: Yukon Potato: Zoe's Pepperoni: Funghi: Brocolli Rabe: Bacon Kale:  Arugula) and Drinks.",
#  'Cold truck: sandwiches: salads: beverages: chips: candy: cookies: coffee: tea: drinks',
#  'Tacos: burritos: quesadillas: soda & water',
#  'Jerk chicken: curry chicken: curry goat: curry dhal: Burritos: Fish: Ox tails: rice: beans: veggies.',
#  'American Food: Hot dogs: pretzels: ice cream: salads: beverages: sandwiches: soup: coffee: pastries:etc.',
#  'Tacos: Burritos: Quesadillas: Tortas',
#  'Peruvian Food Served Hot',
#  'Baos: bowls & drinks',
#  'Breakfast and lunch items with a nod to various cultures',
#  'Meat and vegi rice bowls: meat and vegi salad bowls: meat and vegi wraps: drinks and juices.',
#  'Lobster rolls: crab rolls: lobster burritos: crab burritos: chicken burritos: fish burritos: chicken burritos: poke bowls: soups: chips & soda.',
#  'Tacos: Burritos: Tortas: Quesadillas: Mexican Drinks: Aguas Frescas',
#  'Mexican food: tacos: burritos: tortas: various meat and chicken and fish plate: chile relleno plate: fish plate: bread: flan: rice pudding: bread: fruit juice: vegetable juice: coffee: tea',
#  'Tacos: burritos: quesadillas',
#  'Acai Bowls: Smoothies: Juices',
#  'Ice Cream: Waffle Cones',
#  'Latin Food: Tacos: Pupusas: Vegetables: Salad: Waters: Sodas',
#  'Tacos: Burritos: Quesadillas: Tortas: Nachos: Hot Dogs:Soda: Water: Fruit Drinks',
#  'Tacos: burritos: soda & juice',
#  'Tacos: Burritos: Tortas: Quesadillas: Drinks',
#  'Tacos: Burritos: Quesadillas: Various Drinks',
#  'Rotisserie Chicken; Ribs; Pork Loin; Roasted Potatoes; Chicken Wrap; Kale Salad; Drinks',
#  'Hot dogs: bacon wrap hot dogs: chicken burgers: energy drinks: water & various drinks',
#  'Ice cream: coffee: pastries',
#  'Noodles',
#  'Acai Bowls: Poke Bowls: Smoothies: Juices',
#  'Tacos: Burritos: Quesadillas: Nachos Alambres: Choice of Meat: Carne Asada: Carnitas: Pollo: Al Pastor Camarones',
#  'Noodles: Meat & Drinks',
#  'Rotisserie Chicken: Ribs: Kickass Salad: Potatos w/fat dripping: chicken wrap.',
#  'Pulao Plates & Sandwiches: Various Drinks',
#  'Prepackaged Kettlecorn',
#  'Tacos: Burritos: Tostadas: Flautas: Tostadas: Tortas: Pozole Menudo',
#  'Senor Sisig: Filipino fusion food: tacos: burritos: nachos: rice plates. Various beverages.Chairman Bao: Vegetable and meat sandwiches filled with Asian-flavored meats and vegetables.',
#  'Smoothies: Juice: Salads: Fruit Bowls: Soup',
#  'Mexican; Burritos: Burrito Bowls: Salads',
#  'Multiple Food Trucks & Food Types',
#  'Indian Street Food: Tikka Masala Burritos; Samosas; Sexy Fries (Indian-inspired poutine); Naughty Naans; Deconstructed Samosas; Kathi Rolls; Lassis and Lemonades',
#  'Tacos: burritos: quesadillas: combination plates: tortas: tostadas',
#  'Hot dogs and chili',
#  'Filipino fusion food: taco: burrito: nachos: rice plates',
#  'BBQ PORK SANDWICHGRILL CHICKEN SANDWICHSHIRMP SPRING ROLLSBBQ PORK OVER RICEGRILL CHICKEN OVER RICEBBQ PORK VERMICELLIGRILL CHICKEN VERMICELLIBBQ PORK GARLIC NOODLEGRILL CHICKEN GARLIC NOODLENEW ITEMS:MASALA DOSAPANNER DOSACHICKEN CURRY & RICECHICKEN STEWRICE OR DOSAADD CHEESEADD GHEE',
#  'Brazilian Hamburgers',
#  'kebabs: halal gyro: grilled halal meat: refreshments',
#  'Burritos: Tacos: Quesadillas: Tortas: Carne Asada Fries and various drinks',
#  'Chai Tea',
#  'Chicken Tiki Masala Burritos: Paneer Tiki Masala Burritos: Samosas: Mango Lassi',
#  'Chicken Tikka Masala: Vegetarian Rice Plate: Burritos: Tacos: Mango Lassi',
#  'Coffee: Pastries: Bagels: Sandwiches: Other Items',
#  'Daily rotating menus consisting of various local & organic vegetable: poultry: meat: seafood : rice & bread dishes.',
#  'Everything',
#  'Senor Sisig: Filipino fusion food: tacos: burritos: nachos: rice plates. Various beverages.',
#  'Fruit Salads: Fruit Drinks: Can Soda: Water',
#  'Tacos: Tortas: Burritos',
#  'Halal Gyro over Rice: Halal Chicken over Rice: Halal Gyro: and Chicken Sandwich',
#  'Gyro; Chicken over rice; Gyro over rice;',
#  'Gyro pita bread (Lamb or chicken): lamb over rice: chicken over rice: chicken biryani rice: soft drinks',
#  'Fried Chicken: Fried Fish: Greens: Mac & Cheese: Peach Cobbler: and String beans',
#  'Tacos: burritos: quesadillas: tortas: nachos (refried beans: cheese sauce: salsa fresca): carnes (beef: chicken: marinated pork: fried pork): canned beans: rice: sodas: horchata drinks.',
#  'Tacos: Burritos: Tortas: Quesadillas: Chips & Salsa & Various Beverages',
#  'varies truck to truck',
#  'tacos: burritos: quesadilla: tortas sodas',
#  'tacos',
#  'Tacos: Burritos: Tortas: Quesadillas: Salads: Soup: Fruits: Juices: Soda: Water',
#  'sunflower seeds: crackerjacks: bottled water: peanuts: candy',
#  "rice chicken beef hot dogs and sandwich's and coke and water",
#  'Sandwich: Donuts: Coffee: Soft Serve Ice Cream: Drinks',
#  'chicken sandwich: chicken gyro: chicken biryani',
#  'Snow Cones: Soft Serve Ice Cream & Frozen Virgin Daiquiris',
#  'Tacos: Burritos: Tortas: Quesadillas',
#  'Soft Pretzels: hot dogs: sausage: chips: popcorn: soda: espresso: cappucino: pastries: ice cream: italian sausages: shish-ka-bob: churros: juice: water: various drinks',
#  'Soft pretzels: hot dogs: sausages: chips: popcorn: soda: espresso: cappucino: pastry: ica cream: ices: italian sausage: shish-ka-bob: churros: juice: water: various drinks',
#  'Soft pretzels: hot dogs: sausages: chips: popcorn: sodea: coffee: espresso: cappucino: pastries: ice cream: Italian sausages: shish-ka-bob: churros: juice: water: various drinks.',
#  'South American Peruvian Food - Ceiches: hot wok dishes: hot pastas: rice dishes: and Tapas.',
#  'South American/Peruvian food',
#  'Tacos: Burritos: Tortas: Quesadillas: Sodas: Chips: Candy',
#  'Tortas: burritos: tacos: ensaladas: sodas',
#  'Tacos burritos quesadillas tortas pupusas flautas tamales',
#  'Tacos: Burritos: Hot Dogs: and Hamburgers',
#  'Tacos: burritos: quesadillas: tortas: asada fries: nachos',
#  'Tortas: Burritos: Tacos: Churros: Nachos: Asada Fries',
#  'Various menu items & drinks',
#  '7 Multiple Trucks on rotation (1 on Mission Bay Blvd South & 6 on 4th St).   Serving everything but hot dogs',
#  'Rotisserie chicken: pork loin: ribs: chicken salad wrap: potatoes: roasted seasonal vegetables kale salad: beverages.',
#  'Coffee: Vegan Pastries: Vegan Hot Dogs: Vegan Tamales: Te: Vegan Shakes',
#  'Halal Gyro and Cheesesteaks',
#  'Gyros: Kebobs: refreshments and dessert',
#  'Gyros: Kebabs: soft drinks: and water',
#  'Fruits including mangoes: pineapples: coconuts: watermelon: corn: cucumber: potatoes chips: water: Mexican drinks: sodas: juices: snow cones',
#  'Filipino fusion food: tacos: burritos: nachos: rice plates. Various beverages.',
#  'Filipino Food',
#  'Drip Coffee: Espresso Drinks: Matcha Green Tea: Black Teas: Herbal Teas: Crossaints: Savory and Sweet Breads',
#  'Corndogs: fried burrito: rice placet: soda: water: sandwiches: soup: noodle plates',
#  'Chicken Gyro: Lamb Gyro: Chiken Gyro Plate: Lamb Gyro Plate: Combination Gyro Plate.',
#  'Pernil Asado: Ropa Vieja: Arroz con Pollo: Cuban Sandwich: Croquetas Fritas: Tostones: Platanos Maduros: Yuca Frita',
#  'Cheesesteaks: French Fries: and Drinks',
#  'Burritos: Tacos: Tortas: Quesadillas & Various Drinks.',
#  'Burritos: Giros: Tortas: Quesadillas: Tacos & Various Beverages',
#  'Breakfast - egg: cheese: bacon: tomato: english muffin w/ butter: jam: or nutella: hard boiled eggs: fruit medley: water: coffee: milk: carrot juice: orange juice',
#  'Bread: Pastries: Coffee: Pizza',
#  'Asian Fusion - Japanese Sandwiches/Sliders/Misubi',
#  'American classic slider:  fried chicken slider: fried chicken skin: wedge cut fries: regular cut fries: handcrafted sodas: spring salad',
#  "All types of food except for BBQ on site per fire safety. Partnership with Off the Grid and their fleet of MFF's",
#  'Hot Indian Chai (Tea)',
#  'Hot dogs and related toppings: non alcoholic beverages',
#  'Hot dogs: Bacon wrapped hot dogs: soda: water: sports drinks: energy drinks: chips',
#  'Hot dogs: bacon-wrapped hot dogs: chicken burgers: energy drinks: water and various other drinks.',
#  'Panushos: Salbutes: Salad: Rice: Beans: Cochinita: etc.',
#  'Mexican Food',
#  'Meatloaf: Grilled Cheese: Chicken Sandwich: Caprese Salad: Kale Salad: Fries: Sweet Potato Fries: Mac and Cheese: Mashed Potatoes',
#  'Mangoneadas: Fruit snacks: Chamoyadas: Bionicos',
#  "MOMO Spicy Noodle: POPO's Noodle: Spicy Chicken Noodle: Rice Noodles",
#  'Lomo Saltado: Jalea: Ceviche: Calamari Tilapia Plates: Chicken: Soda: Water.',
#  'Lomo Saltado: Jalea: Ceviche: Calamar: Tilapia plate: chicken special. Soda: Water.',
#  'Latin Food: Tacos: Pupusas: Vegetables: Salad: Water: Sodas',
#  'Kettle Corn: Funnel Cakes: Waffles: Lemonade',
#  'Kettle Corn: Funnel Cakes: Lemonade: Beverages: Flan: Hot Dogs: Falafel: Hot and Cold Sandwiches: French Fries: Baklava and Pastries',
#  'Indian Chai (Tea)',
#  'Ice cream & Waffle cones',
#  'Ice Cream: Donuts',
#  'Ice Cream & Waffle Cones',
#  'Hotdogs: chips: soda: nuts: crackers',
#  'Hot dogs: sausages: cheesesteaks: chips: drinks',
#  'Hot dogs: condiments: soft pretzels: soft drinks: coffee:cold beverages: pastries: bakery goods: cookies: icecream: candy: soups: churros: chestnuts: nuts: fresh fruit: fruit juices: desserts: potato chips and popcorn.',
#  'various styles of hot dogs & sausages: chips: breakfast sandwiches: chili: soda: water:']

# %% [markdown]
# 3. Manually reassigning food types to new labels

# %%
# food types are extremely varied: going to assign categories for each to fit into
# e.g. Mexican, Japanese, Breakfast, Hot Dogs, ...
foodtier2 = dict.fromkeys(foodtype, None)
for item in foodtype:
    if 'COLD TRUCK' in item.upper() or 'CRACKERJACKS' in item.upper() or 'KETTLE' in item.upper():
        foodtier2[item] = 'COLD TRUCK'
    elif 'EVERYTHING' in item.upper() or 'VARIES' in item.upper() or 'ALL TYPES' in item.upper():
        foodtier2[item] = 'OTHER'
    elif 'FILIPINO' in item.upper():
        foodtier2[item] = 'FILIPINO'
    elif ('MEXICAN' in item.upper() or 'TACO' in item.upper() or 'BURRITO' in item.upper() or 'COCHINITA' in item.upper() or 'FRUIT SALADS: FRUIT DRINKS' in item.upper() or 'MANGONEADA' in item.upper()) and 'MASALA' not in item.upper() and 'JERK' not in item.upper():
        foodtier2[item] = 'MEXICAN'
    elif ('INDIAN' in item.upper() or 'MASALA' in item.upper() or 'PULAO' in item.upper() or 'CHAI' in item.upper()) and 'BBQ PORK' not in item.upper():
        foodtier2[item] = 'INDIAN & SOUTH ASIAN'
    elif 'BRAZILIAN' in item.upper():
        foodtier2[item] = 'BRAZILIAN'
    elif 'PERUVIAN' in item.upper() or 'LOMO SALTADO' in item.upper():
        foodtier2[item] = 'PERUVIAN'
    elif 'JERK' in item.upper() or 'PLANTAIN' in item.upper():
        foodtier2[item] = 'JAMAICAN'
    elif 'CUBAN' in item.upper():
        foodtier2[item] = 'CUBAN'
    elif 'JAPANESE' in item.upper():
        foodtier2[item] = 'JAPANESE'
    elif 'VEGAN' in item.upper():
        foodtier2[item] = 'VEGAN'
    elif 'GYRO' in item.upper():
        foodtier2[item] = 'GYRO'
    elif 'POKE BOWL' in item.upper():
        foodtier2[item] = 'POKE BOWL'
    elif 'HOT DOG' in item.upper() or 'HOTDOG' in item.upper() or 'BURGER' in item.upper():
        foodtier2[item] = 'HOT DOGS & BURGERS'
    elif 'ICE CREAM' in item.upper():
        foodtier2[item] = 'ICE CREAM'
    elif 'PASTRY' in item.upper() or 'PASTRIES' in item.upper() or 'BREAKFAST' in item.upper() or 'CROISSA' in item.upper():
        foodtier2[item] = 'BREAKFAST'
    elif 'PIZZA' in item.upper():
        foodtier2[item] = 'PIZZA'
    elif 'PERUVIAN' in item.upper():
        foodtier2[item] = 'PERUVIAN'
    elif 'BAO' in item.upper():
        foodtier2[item] = 'BAO'
    elif 'ACAI' in item.upper() or 'FRUIT DRINK' in item.upper() or 'FRUITS' in item.upper() or 'SMOOTHIE' in item.upper():
        foodtier2[item] = 'SMOOTHIE'
    elif ('NOODLE' in item.upper() or 'RICE BOWL' in item.upper()) and 'BBQ PORK' not in item.upper():
        foodtier2[item] = 'NOODLES & RICE BOWLS'
    elif 'RIB' in item.upper() or 'FRIED CHICKEN' in item.upper() or 'MEATLOAF' in item.upper() or 'BBQ' in item.upper():
        foodtier2[item] = 'AMERICAN'
    elif 'CHEESESTEAK' in item.upper():
        foodtier2[item] = 'CHEESESTEAK'
    else:
        foodtier2[item] = 'OTHER'

# %%
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(pd.DataFrame.from_dict(foodtier2, orient = 'index', columns = ['FoodTier2']))
# Out:
#                                                                FoodTier2
# Cold Truck: Sandwiches: Noodles:  Pre-packaged ...            COLD TRUCK
# Burgers: melts: hot dogs: burritos:sandwiches: ...               MEXICAN
# Cold Truck: Pre-packaged sandwiches: snacks: fr...            COLD TRUCK
# Cold Truck: Hamburger: cheeseburgers: hot dogs:...            COLD TRUCK
# Ice Cream: Pre-Packaged Chips: Candies: Bottled...             ICE CREAM
# COLD TRUCK. Deli: bbq chicken skewer: Chinese s...            COLD TRUCK
# Cold Truck: Soft drinks: cup cakes: potato chip...            COLD TRUCK
# Cold Truck: Corn Dogs: Noodle Soups: Candy: Pre...            COLD TRUCK
# Hot dogs: condiments: soft pretzels: soft drink...    HOT DOGS & BURGERS
# Cold Truck: Breakfast: Sandwiches: Salads: Pre-...            COLD TRUCK
# Cold Truck: Hot/Cold Sandwiches: Water: Soda: J...            COLD TRUCK
# Bonito Poke Bowls & Various Drinks                             POKE BOWL
# Cold Truck: Burrito: Corn Dog: Salads: Sandwich...            COLD TRUCK
# Mexican Food: Yucatan Food: Street Food                          MEXICAN
# everything except for hot dogs                                     OTHER
# Various types of meat: veggie: and seafood bowls.                  OTHER
# Hot coffee: iced coffee: hot chocolate: tea: pa...             BREAKFAST
# Artisan Pizzas (Margherita: Yukon Potato: Zoe's...                 PIZZA
# Cold truck: sandwiches: salads: beverages: chip...            COLD TRUCK
# Tacos: burritos: quesadillas: soda & water                       MEXICAN
# Jerk chicken: curry chicken: curry goat: curry ...              JAMAICAN
# American Food: Hot dogs: pretzels: ice cream: s...    HOT DOGS & BURGERS
# Tacos: Burritos: Quesadillas: Tortas                             MEXICAN
# Peruvian Food Served Hot                                        PERUVIAN
# Baos: bowls & drinks                                                 BAO
# Breakfast and lunch items with a nod to various...             BREAKFAST
# Meat and vegi rice bowls: meat and vegi salad b...  NOODLES & RICE BOWLS
# Lobster rolls: crab rolls: lobster burritos: cr...               MEXICAN
# Tacos: Burritos: Tortas: Quesadillas: Mexican D...               MEXICAN
# Mexican food: tacos: burritos: tortas: various ...               MEXICAN
# Tacos: burritos: quesadillas                                     MEXICAN
# Acai Bowls: Smoothies: Juices                                   SMOOTHIE
# Ice Cream: Waffle Cones                                        ICE CREAM
# Latin Food: Tacos: Pupusas: Vegetables: Salad: ...               MEXICAN
# Tacos: Burritos: Quesadillas: Tortas: Nachos: H...               MEXICAN
# Tacos: burritos: soda & juice                                    MEXICAN
# Tacos: Burritos: Tortas: Quesadillas: Drinks                     MEXICAN
# Tacos: Burritos: Quesadillas: Various Drinks                     MEXICAN
# Rotisserie Chicken; Ribs; Pork Loin; Roasted Po...              AMERICAN
# Hot dogs: bacon wrap hot dogs: chicken burgers:...    HOT DOGS & BURGERS
# Ice cream: coffee: pastries                                    ICE CREAM
# Noodles                                             NOODLES & RICE BOWLS
# Acai Bowls: Poke Bowls: Smoothies: Juices                      POKE BOWL
# Tacos: Burritos: Quesadillas: Nachos Alambres: ...               MEXICAN
# Noodles: Meat & Drinks                              NOODLES & RICE BOWLS
# Rotisserie Chicken: Ribs: Kickass Salad: Potato...              AMERICAN
# Pulao Plates & Sandwiches: Various Drinks           INDIAN & SOUTH ASIAN
# Prepackaged Kettlecorn                                        COLD TRUCK
# Tacos: Burritos: Tostadas: Flautas: Tostadas: T...               MEXICAN
# Senor Sisig: Filipino fusion food: tacos: burri...              FILIPINO
# Smoothies: Juice: Salads: Fruit Bowls: Soup                     SMOOTHIE
# Mexican; Burritos: Burrito Bowls: Salads                         MEXICAN
# Multiple Food Trucks & Food Types                                  OTHER
# Indian Street Food: Tikka Masala Burritos; Samo...  INDIAN & SOUTH ASIAN
# Tacos: burritos: quesadillas: combination plate...               MEXICAN
# Hot dogs and chili                                    HOT DOGS & BURGERS
# Filipino fusion food: taco: burrito: nachos: ri...              FILIPINO
# BBQ PORK SANDWICHGRILL CHICKEN SANDWICHSHIRMP S...              AMERICAN
# Brazilian Hamburgers                                           BRAZILIAN
# kebabs: halal gyro: grilled halal meat: refresh...                  GYRO
# Burritos: Tacos: Quesadillas: Tortas: Carne Asa...               MEXICAN
# Chai Tea                                            INDIAN & SOUTH ASIAN
# Chicken Tiki Masala Burritos: Paneer Tiki Masal...  INDIAN & SOUTH ASIAN
# Chicken Tikka Masala: Vegetarian Rice Plate: Bu...  INDIAN & SOUTH ASIAN
# Coffee: Pastries: Bagels: Sandwiches: Other Items              BREAKFAST
# Daily rotating menus consisting of various loca...                 OTHER
# Everything                                                         OTHER
# Senor Sisig: Filipino fusion food: tacos: burri...              FILIPINO
# Fruit Salads: Fruit Drinks: Can Soda: Water                      MEXICAN
# Tacos: Tortas: Burritos                                          MEXICAN
# Halal Gyro over Rice: Halal Chicken over Rice: ...                  GYRO
# Gyro; Chicken over rice; Gyro over rice;                            GYRO
# Gyro pita bread (Lamb or chicken): lamb over ri...                  GYRO
# Fried Chicken: Fried Fish: Greens: Mac & Cheese...              AMERICAN
# Tacos: burritos: quesadillas: tortas: nachos (r...               MEXICAN
# Tacos: Burritos: Tortas: Quesadillas: Chips & S...               MEXICAN
# varies truck to truck                                              OTHER
# tacos: burritos: quesadilla: tortas sodas                        MEXICAN
# tacos                                                            MEXICAN
# Tacos: Burritos: Tortas: Quesadillas: Salads: S...               MEXICAN
# sunflower seeds: crackerjacks: bottled water: p...            COLD TRUCK
# rice chicken beef hot dogs and sandwich's and c...    HOT DOGS & BURGERS
# Sandwich: Donuts: Coffee: Soft Serve Ice Cream:...             ICE CREAM
# chicken sandwich: chicken gyro: chicken biryani                     GYRO
# Snow Cones: Soft Serve Ice Cream & Frozen Virgi...             ICE CREAM
# Tacos: Burritos: Tortas: Quesadillas                             MEXICAN
# Soft Pretzels: hot dogs: sausage: chips: popcor...    HOT DOGS & BURGERS
# Soft pretzels: hot dogs: sausages: chips: popco...    HOT DOGS & BURGERS
# Soft pretzels: hot dogs: sausages: chips: popco...    HOT DOGS & BURGERS
# South American Peruvian Food - Ceiches: hot wok...              PERUVIAN
# South American/Peruvian food                                    PERUVIAN
# Tacos: Burritos: Tortas: Quesadillas: Sodas: Ch...               MEXICAN
# Tortas: burritos: tacos: ensaladas: sodas                        MEXICAN
# Tacos burritos quesadillas tortas pupusas flaut...               MEXICAN
# Tacos: Burritos: Hot Dogs: and Hamburgers                        MEXICAN
# Tacos: burritos: quesadillas: tortas: asada fri...               MEXICAN
# Tortas: Burritos: Tacos: Churros: Nachos: Asada...               MEXICAN
# Various menu items & drinks                                        OTHER
# 7 Multiple Trucks on rotation (1 on Mission Bay...                 OTHER
# Rotisserie chicken: pork loin: ribs: chicken sa...              AMERICAN
# Coffee: Vegan Pastries: Vegan Hot Dogs: Vegan T...                 VEGAN
# Halal Gyro and Cheesesteaks                                         GYRO
# Gyros: Kebobs: refreshments and dessert                             GYRO
# Gyros: Kebabs: soft drinks: and water                               GYRO
# Fruits including mangoes: pineapples: coconuts:...               MEXICAN
# Filipino fusion food: tacos: burritos: nachos: ...              FILIPINO
# Filipino Food                                                   FILIPINO
# Drip Coffee: Espresso Drinks: Matcha Green Tea:...                 OTHER
# Corndogs: fried burrito: rice placet: soda: wat...               MEXICAN
# Chicken Gyro: Lamb Gyro: Chiken Gyro Plate: Lam...                  GYRO
# Pernil Asado: Ropa Vieja: Arroz con Pollo: Cuba...                 CUBAN
# Cheesesteaks: French Fries: and Drinks                       CHEESESTEAK
# Burritos: Tacos: Tortas: Quesadillas & Various ...               MEXICAN
# Burritos: Giros: Tortas: Quesadillas: Tacos & V...               MEXICAN
# Breakfast - egg: cheese: bacon: tomato: english...             BREAKFAST
# Bread: Pastries: Coffee: Pizza                                 BREAKFAST
# Asian Fusion - Japanese Sandwiches/Sliders/Misubi               JAPANESE
# American classic slider:  fried chicken slider:...              AMERICAN
# All types of food except for BBQ on site per fi...                 OTHER
# Hot Indian Chai (Tea)                               INDIAN & SOUTH ASIAN
# Hot dogs and related toppings: non alcoholic be...    HOT DOGS & BURGERS
# Hot dogs: Bacon wrapped hot dogs: soda: water: ...    HOT DOGS & BURGERS
# Hot dogs: bacon-wrapped hot dogs: chicken burge...    HOT DOGS & BURGERS
# Panushos: Salbutes: Salad: Rice: Beans: Cochini...               MEXICAN
# Mexican Food                                                     MEXICAN
# Meatloaf: Grilled Cheese: Chicken Sandwich: Cap...              AMERICAN
# Mangoneadas: Fruit snacks: Chamoyadas: Bionicos                  MEXICAN
# MOMO Spicy Noodle: POPO's Noodle: Spicy Chicken...  NOODLES & RICE BOWLS
# Lomo Saltado: Jalea: Ceviche: Calamari Tilapia ...              PERUVIAN
# Lomo Saltado: Jalea: Ceviche: Calamar: Tilapia ...              PERUVIAN
# Latin Food: Tacos: Pupusas: Vegetables: Salad: ...               MEXICAN
# Kettle Corn: Funnel Cakes: Waffles: Lemonade                  COLD TRUCK
# Kettle Corn: Funnel Cakes: Lemonade: Beverages:...            COLD TRUCK
# Indian Chai (Tea)                                   INDIAN & SOUTH ASIAN
# Ice cream & Waffle cones                                       ICE CREAM
# Ice Cream: Donuts                                              ICE CREAM
# Ice Cream & Waffle Cones                                       ICE CREAM
# Hotdogs: chips: soda: nuts: crackers                  HOT DOGS & BURGERS
# Hot dogs: sausages: cheesesteaks: chips: drinks       HOT DOGS & BURGERS
# Hot dogs: condiments: soft pretzels: soft drink...    HOT DOGS & BURGERS
# various styles of hot dogs & sausages: chips: b...    HOT DOGS & BURGERS

# %%
# now want to create an even more general category
# e.g. Mexican, Peruvian, Cuban would all become Latin
foodtier1_list = []
for item in foodtier2.values():
    foodtier1_list.append(item)

# %%
foodtier1 = dict.fromkeys(foodtier1_list, None)

# %%
for item in foodtier1_list:
    if 'MEXICAN' in item.upper() or 'PERUVIAN' in item.upper() or 'CUBAN' in item.upper() or 'BRAZILIAN' in item.upper():
        foodtier1[item] = 'LATIN'
    elif 'BAO' in item.upper() or 'JAPANESE' in item.upper() or 'NOODLE' in item.upper():
        foodtier1[item] = 'EAST ASIAN'
    elif 'INDIAN' in item.upper() or 'FILIPINO' in item.upper():
        foodtier1[item] = 'SOUTH ASIAN'
    elif 'JAMAICAN' in item.upper():
        foodtier1[item] = 'CARIBBEAN'
    elif 'AMERICAN' in item.upper() or 'HOT DOG' in item.upper() or 'ICE CREAM' in item.upper() or 'BREAKFAST' in item.upper() or 'CHEESESTEAK' in item.upper() or 'VEGAN' in item.upper() or 'PIZZA' in item.upper() or 'POKE' in item.upper() or 'BREAKFAST' in item.upper():
        foodtier1[item] = 'AMERICAN'
    elif 'GYRO' in item.upper():
        foodtier1[item] = 'GREEK & MIDDLE EASTERN'
    else:
        foodtier1[item] = 'OTHER'

# %%
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(pd.DataFrame.from_dict(foodtier1, orient = 'index', columns = ['FoodTier1']))
# Out:
#                                    FoodTier1
# COLD TRUCK                             OTHER
# MEXICAN                                LATIN
# ICE CREAM                           AMERICAN
# HOT DOGS & BURGERS                  AMERICAN
# POKE BOWL                           AMERICAN
# OTHER                                  OTHER
# BREAKFAST                           AMERICAN
# PIZZA                               AMERICAN
# JAMAICAN                           CARIBBEAN
# PERUVIAN                               LATIN
# BAO                               EAST ASIAN
# NOODLES & RICE BOWLS              EAST ASIAN
# SMOOTHIE                               OTHER
# AMERICAN                            AMERICAN
# INDIAN & SOUTH ASIAN             SOUTH ASIAN
# FILIPINO                         SOUTH ASIAN
# BRAZILIAN                              LATIN
# GYRO                  GREEK & MIDDLE EASTERN
# VEGAN                               AMERICAN
# CUBAN                                  LATIN
# CHEESESTEAK                         AMERICAN
# JAPANESE                          EAST ASIAN

# %% [markdown]
# 4. Creating new columns in original dataframe for our Tier1 and Tier2 foodtype labels

# %%
df['FoodTier2']= df['FoodItems'].map(foodtier2)
df['FoodTier1']= df['FoodTier2'].map(foodtier1)

# %%
df.tail(10)
# Out:
#      locationid                         Applicant FacilityType       cnn  \
# 471     1587560                     Brazuca Grill        Truck   5070000
# 472     1591827                         Cochinita        Truck   3285000
# 473     1575192                   Park's Catering        Truck   8483000
# 474     1587541                     Brazuca Grill        Truck   1232000
# 475     1575193                   Park's Catering        Truck   8700000
# 476     1591829                         Cochinita        Truck   4806101
# 477     1591822                         Cochinita        Truck   1329000
# 478     1569152      Datam SF LLC dba Anzu To You        Truck  12463000
# 479     1587553                     Brazuca Grill        Truck    197101
# 480     1585474  San Francisco Street Foods, Inc.    Push Cart   7038000
#
#                                    LocationDescription            Address  \
# 471   EDDY ST: BUCHANAN ST to WEBSTER ST (1300 - 1399)       1346 EDDY ST
# 472  BRYANT ST: 04TH ST \ I-80 E OFF RAMP to 05TH S...      617 BRYANT ST
# 473  LOOMIS ST: BARNEVELD AVE \ MCKINNON AVE to OAK...       10 LOOMIS ST
# 474  23RD ST: START: 100-699 BLOCK to ILLINOIS ST (...        601 23RD ST
# 475  MARIN ST: KANSAS ST to HWY 101 N ON RAMP (2500...      2525 MARIN ST
# 476  DIVISADERO ST: MCALLISTER ST to GOLDEN GATE AV...  999 DIVISADERO ST
# 477      24TH ST: UTAH ST to POTRERO AVE (2600 - 2699)       2601 24TH ST
# 478  TAYLOR ST: BAY ST to NORTH POINT ST (2500 - 2599)     2535 TAYLOR ST
# 479  03RD ST: MARIN ST to ARTHUR AVE \ CARGO WAY (3...       3255 03RD ST
# 480          HOWARD ST: 03RD ST to 04TH ST (700 - 799)      701 HOWARD ST
#
#      blocklot block   lot       permit  ... PriorPermit  \
# 471   0733014  0733   014  21MFF-00154  ...           1
# 472   3777055  3777   055  22MFF-00021  ...           1
# 473   5560100  5560   100  21MFF-00115  ...           1
# 474   4232010  4232   010  21MFF-00154  ...           1
# 475  4343001D  4343  001D  21MFF-00115  ...           1
# 476   1156034  1156   034  22MFF-00021  ...           1
# 477   4264001  4264   001  22MFF-00020  ...           0
# 478   0029007  0029   007  21MFF-00106  ...           0
# 479   4377001  4377   001  21MFF-00154  ...           1
# 480   3734091  3734   091  21MFF-00145  ...           1
#
#              ExpirationDate                                   Location  \
# 471  11/15/2022 12:00:00 AM   (37.78186711757412, -122.42988524760261)
# 472  11/15/2022 12:00:00 AM  (37.779051111573146, -122.39830388133372)
# 473  11/15/2022 12:00:00 AM   (37.74378392338268, -122.40378882961045)
# 474  11/15/2022 12:00:00 AM  (37.755030726766726, -122.38453073422282)
# 475  11/15/2022 12:00:00 AM   (37.74761607223309, -122.40197697572432)
# 476  11/15/2022 12:00:00 AM  (37.778384300969044, -122.43878238856672)
# 477  11/15/2022 12:00:00 AM   (37.752822368121485, -122.4055319192157)
# 478  11/15/2022 12:00:00 AM  (37.805885350100986, -122.41594524663745)
# 479  11/15/2022 12:00:00 AM  (37.748445338837655, -122.38687903197963)
# 480  11/15/2022 12:00:00 AM  (37.783513351245354, -122.40081339110537)
#
#      Fire Prevention Districts  Police Districts  Supervisor Districts  \
# 471                        7.0               9.0                  11.0
# 472                        6.0               2.0                   9.0
# 473                       10.0               3.0                   8.0
# 474                       10.0               3.0                   8.0
# 475                       10.0               3.0                   8.0
# 476                       15.0               5.0                  11.0
# 477                       10.0               4.0                   8.0
# 478                        5.0               1.0                  10.0
# 479                       10.0               3.0                   8.0
# 480                        6.0               2.0                   9.0
#
#     Zip Codes Neighborhoods (old)           FoodTier2   FoodTier1
# 471   29490.0                41.0          COLD TRUCK       OTHER
# 472   28856.0                34.0             MEXICAN       LATIN
# 473      58.0                 1.0          COLD TRUCK       OTHER
# 474   28856.0                29.0          COLD TRUCK       OTHER
# 475      58.0                 1.0          COLD TRUCK       OTHER
# 476   29490.0                41.0             MEXICAN       LATIN
# 477   28859.0                19.0             MEXICAN       LATIN
# 478     308.0                23.0            JAPANESE  EAST ASIAN
# 479      58.0                 1.0          COLD TRUCK       OTHER
# 480   28853.0                34.0  HOT DOGS & BURGERS    AMERICAN
#
# [10 rows x 31 columns]

# %% [markdown]
# ### Mapping Visualization
# Using Folium to plot city location against type of cuisine

# %% [markdown]
# 5. Import packages and initialize map in SF

# %%
import folium

intro_map = folium.Map(location=[37.761229, -122.447213],zoom_start=13)

# %%
intro_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95540969ab19da69a4bab55ca8f9bb0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95540969ab19da69a4bab55ca8f9bb0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95540969ab19da69a4bab55ca8f9bb0c = L.map(
#                 &quot;map_95540969ab19da69a4bab55ca8f9bb0c&quot;,
#                 {
#                     center: [37.761229, -122.447213],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_83131d3b9da3371026c62d4a6c427236 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_95540969ab19da69a4bab55ca8f9bb0c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 6. Create icons to better visualize specific cuisines

# %%
# create dictionary and choose which icons and colours should represent each cuisine
food_icons = dict.fromkeys(df['FoodTier1'], None)

# %%
for key in food_icons.keys():
    if key == 'OTHER':
        food_icons[key] = ['bottle-water','lightgray']
    if key == 'AMERICAN':
        food_icons[key] = ['hotdog','beige']
    if key == 'LATIN':
        food_icons[key] = ['pepper-hot','red']
    if key == 'CARIBBEAN':
        food_icons[key] = ['lemon','lightgreen']
    if key == 'EAST ASIAN':
        food_icons[key] = ['bowl-rice','black']
    if key == 'GREEK & MIDDLE EASTERN':
        food_icons[key] = ['fish','lightblue']
    if key == 'SOUTH ASIAN':
        food_icons[key] = ['bowl-food','orange']

# %%
for index in df.index:
    for k,v in food_icons.items():
        if df['FoodTier1'][index]==k:
            folium.Marker(
                location=[eval(df['Location'][index])[0],eval(df['Location'][index])[1]],
                popup=df['FoodItems'][index],
                icon=folium.Icon(color=v[1],prefix='fa',icon=v[0]),
            ).add_to(intro_map)

# %%
intro_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5578daa844d64ea67f5d9baa4be180fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5578daa844d64ea67f5d9baa4be180fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5578daa844d64ea67f5d9baa4be180fa = L.map(
#                 &quot;map_5578daa844d64ea67f5d9baa4be180fa&quot;,
#                 {
#                     center: [37.761229, -122.447213],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1570f58607737082233f1a6da67a422c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5578daa844d64ea67f5d9baa4be180fa);
#
#
#             var marker_7f793c6d12d2f237f16f565a95616de9 = L.marker(
#                 [37.793262206923096, -122.4017890913628],
#                 {}
#             ).addTo(map_5578daa844d64ea67f5d9baa4be180fa);
#
#
#             var icon_e3b9647986c3929155d752e25b8e395c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;hotdog&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7f793c6d12d2f237f16f565a95616de9.setIcon(icon_e3b9647986c3929155d752e25b8e395c);
#
#
#         var popup_141f6f71b146bd6820add89ad23b2016 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6f8c0f6dc696c963bb66ca4c7808b0c = $(`&lt;div id=&quot;html_e6f8c0f6dc696c963bb66ca4c7808b0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bonito Poke&lt;/div&gt;`)[0];
#                 popup_141f6f71b146bd6820add89ad23b2016.setContent(html_e6f8c0f6dc696c963bb66ca4c7808b0c);
#
#
#
#         marker_7f793c6d12d2f237f16f565a95616de9.bindPopup(popup_141f6f71b146bd6820add89ad23b2016)
#         ;
#
#
#
#
#             var marker_9f209a8540e107f7099f1de240ee65fc = L.marker(
#                 [37.786856111883054, -122.40689189299718],
#                 {}
#             ).addTo(map_5578daa844d64ea67f5d9baa4be180fa);
#
#
#             var icon_f63bf73d0c440d9f7904079d88d9aa00 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;hotdog&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9f209a8540e107f7099f1de240ee65fc.setIcon(icon_f63bf73d0c440d9f7904079d88d9aa00);
#
#
#         var popup_71ed85e80d01ab72a5f5faaf777864a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_51504b6f7350d2e6e0e269de7f2422c9 = $(`&lt;div id=&quot;html_51504b6f7350d2e6e0e269de7f2422c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The New York Frankfurter Co. of CA, Inc. DBA: Annie&#x27;s Hot Dogs&lt;/div&gt;`)[0];
#                 popup_71ed85e80d01ab72a5f5faaf777864a4.setContent(html_51504b6f7350d2e6e0e269de7f2422c9);
#
#
#
#         marker_9f209a8540e107f7099f1de240ee65fc.bindPopup(popup_71ed85e80d01ab72a5f5faaf777864a4)
#         ;
#
#
#
#
#             var marker_8f498eaff18f2b390833d7d60f35af6e = L.marker(
#                 [37.74530890865633, -122.40342005999852],
#                 {}
#             ).addTo(map_5578daa844d64ea67f5d9baa4be180fa);
#
#
#             var icon_0ea04f13173062b7ee304b65f0b7df80 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;hotdog&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8f498eaff18f2b390833d7d60f35af6e.setIcon(icon_0ea04f13173062b7ee304b65f0b7df80);
#
#
#         var popup_bd00e75a00989c36163f7eb74cb6b058 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af22c2408985201b8b9de810640c77b4 = $(`&lt;div id=&quot;html_af22c2408985201b8b9de810640c77b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Reecees Soulicious&lt;/div&gt;`)[0];
#                 popup_bd00e75a00989c36163f7eb74cb6b058.setContent(html_af22c2408985201b8b9de810640c77b4);
#
#
#
#         marker_8f498eaff18f2b390833d7d60f35af6e.bindPopup(popup_bd00e75a00989c36163f7eb74cb6b058)
#         ;
#
#
#
#
#             var marker_cab4ca7f7dab8755fc18bd64788d6a2c = L.marker(
#                 [37.78798864899528, -122.39610066847152],
#                 {}
#             ).addTo(map_5578daa844d64ea67f5d9baa4be180fa);
#
#
#             var icon_97bfa231d96a9ab84dad214be7908e31 = L.AwesomeMarkers.i

# %%
intro_map.save("foodtruck.html")
